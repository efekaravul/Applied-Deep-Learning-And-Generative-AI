# %%
import torch

# %%
tensor = torch.arange(0,50,5)

# %%
tensor
# Out:
# tensor([ 0,  5, 10, 15, 20, 25, 30, 35, 40, 45])

# %%
tensor.min()
# Out:
# tensor(0)

# %%
tensor.max()
# Out:
# tensor(45)

# %%
tensor.sum()
# Out:
# tensor(225)

# %%
tensor.median()
# Out:
# tensor(20)

# %%
tensor = tensor.type(torch.float)

# %%
tensor
# Out:
# tensor([ 0.,  5., 10., 15., 20., 25., 30., 35., 40., 45.])

# %%
tensor.mean()
# Out:
# tensor(22.5000)

# %%
tensor.max()
# Out:
# tensor(45.)

# %%
tensor.argmax()
# Out:
# tensor(9)

# %%
tensor.argmin()
# Out:
# tensor(0)

# %%
tensor[9]
# Out:
# tensor(45.)

# %%
tensor[0]
# Out:
# tensor(0.)
